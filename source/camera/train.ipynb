# %% [markdown]
# ### YOLO v8 학습

# %%
from ultralytics import YOLO
import torch 
print(torch.__version__)
# Out:
# 2.0.0+cu118

# %% [markdown]
# ### Roboflow에서 데이터 셋 다운로드

# %% [markdown]
# robowflow에서 train set을 만든다음 export를 code로 진행하여 복붙한다.

# %%
from roboflow import Roboflow
# " "에 복사한 정보가 들어가 있다.
rf = Roboflow(api_key=" ")
project = rf.workspace(" ").project(" ")
dataset = project.version(6).download(" ")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.107, to fix: `pip install ultralytics<=8.0.20`
# ...
# Extracting Dataset Version Zip to HADA_segment-6 in yolov8:: 100%|██████████| 780/780 [00:00<00:00, 2744.48it/s]

# %% [markdown]
# ### YOLO에서 사전에 학습된 가중치 기반으로 YOLO 모델 선언

# %%
model = YOLO("yolov8l-seg.pt")

# %% [markdown]
# ### data에 학습된 데이터 기반으로 모델 학습

# %%
model.train(task="segment", data=" \\다운 받은\\ .yaml\\ 경로를 입력 ", batch=-1, imgsz=640, device=0, plots=True, save=True, epochs = 100)
# Out:
# New https://pypi.org/project/ultralytics/8.0.113 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.107  Python-3.10.10 torch-2.0.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# ...
